# %% [markdown]
# ### 🛠️ Day 5 Tasks:
#
# 1. Implement incremental MERGE
# 2. Query historical versions
# 3. Optimize tables
# 4. Clean old files

# %% [markdown]
# ## Task 1: Implement Incremental MERGE

# %%
#Read November CSV
Nov_events = spark.read.csv(
    "/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv",
    header=True,
    inferSchema=True
)

# %%
Nov_events.createOrReplaceTempView("incremental_events")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
MERGE INTO workspace.ecommerce.oct_events_delta_sql AS target
USING incremental_events AS source
ON target.event_time = source.event_time
   AND target.user_id = source.user_id
   AND target.product_id = source.product_id

WHEN MATCHED THEN
  UPDATE SET *

WHEN NOT MATCHED THEN
  INSERT *
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>67501979</td><td>0</td><td>0</td><td>67501979</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Validate Incremental Load

# %%
# %sql
SELECT COUNT(*) AS total_rows
FROM workspace.ecommerce.oct_events_delta_sql;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th></tr></thead><tbody><tr><td>109950743</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Task 2: Query Historical Versions (Delta Time Travel)

# %% [markdown]
# View Delta Table History

# %%
# %sql
DESCRIBE HISTORY workspace.ecommerce.oct_events_delta_sql;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>2</td><td>2026-01-15T10:34:06.000Z</td><td>78119440703336</td><td>karthika2738@gmail.com</td><td>MERGE</td><td>Map(predicate -> ["(((event_time#13201 = event_time#13181) AND (user_id#13208 = user_id#13188)) AND (product_id#13203 = product_id#13183))"], clusterBy -> [], matchedPredicates -> [{"actionType":"update"}], statsOnLoad -> true, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [{"actionType":"insert"}])</td><td>null</td><td>List(2538393327508024)</td><td>0115-102806-588uh7nr-v2n</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 68, numTargetBytesAdded -> 1171886398, numTargetBytesRemoved -> 0, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 0, executionTimeMs -> 84187, materializeSourceTimeMs -> 45304, numTargetRowsInserted -> 67501979, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 18575, numTargetRowsUpdated -> 0, numOutputRows -> 67501979, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 67501979, numTargetFilesRemoved -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 20165)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>1</td><td>2026-01-15T03:45:13.000Z</td><td>78119440703336</td><td>karthika2738@gmail.com</td><td>MERGE</td><td>Map(predicate -> ["(((event_time#13257 = event_time#13236) AND (user_id#13264 = user_id#13243)) AND (product_id#13259 = product_id#13238))"], clusterBy -> [], matchedPredicates -> [], statsOnLoad -> false, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [{"actionType":"insert"}])</td><td>null</td><td>List(3604489690824905)</td><td>0115-033354-z5wk3ccl-v2n</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 0, numTargetBytesAdded -> 0, numTargetBytesRemoved -> 0, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 0, executionTimeMs -> 29904, materializeSourceTimeMs -> 12, numTargetRowsInserted -> 0, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 0, numTargetRowsUpdated -> 0, numOutputRows -> 0, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 42448764, numTargetFilesRemoved -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 29796)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>0</td><td>2026-01-14T16:25:39.000Z</td><td>78119440703336</td><td>karthika2738@gmail.com</td><td>CREATE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true"}, statsOnLoad -> true)</td><td>null</td><td>List(3604489690824905)</td><td>0114-162320-q4l93jah-v2n</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 12, numOutputRows -> 42448764, numOutputBytes -> 731915974)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Query a Specific Version (VERSION AS OF)

# %%
# %sql
SELECT COUNT(*)
FROM workspace.ecommerce.oct_events_delta_sql
VERSION AS OF 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>42448764</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Compare with Current Version

# %%
# %sql
SELECT COUNT(*)
FROM workspace.ecommerce.oct_events_delta_sql;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>109950743</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Query by Timestamp (TIMESTAMP AS OF)

# %%
# %sql
SELECT *
FROM workspace.ecommerce.oct_events_delta_sql
TIMESTAMP AS OF '2026-01-14 21:00:00'
LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_time</th><th>event_type</th><th>product_id</th><th>category_id</th><th>category_code</th><th>brand</th><th>price</th><th>user_id</th><th>user_session</th></tr></thead><tbody><tr><td>2019-10-26T07:55:54.000Z</td><td>view</td><td>45300083</td><td>2106075662325383725</td><td>kids.swing</td><td>joie</td><td>197.43</td><td>538181220</td><td>70d25815-9efd-4535-a1e3-5d209006ca27</td></tr><tr><td>2019-10-26T07:55:54.000Z</td><td>view</td><td>3701134</td><td>2053013565983425517</td><td>appliances.environment.vacuum</td><td>bosch</td><td>90.07</td><td>525753452</td><td>d8ee9530-fc77-421c-be80-54bb03e0d1a2</td></tr><tr><td>2019-10-26T07:55:54.000Z</td><td>view</td><td>1307238</td><td>2053013558920217191</td><td>computers.notebook</td><td>lenovo</td><td>303.46</td><td>549408570</td><td>bc4a7104-1277-4c8b-8191-9e2189bfeeee</td></tr><tr><td>2019-10-26T07:55:54.000Z</td><td>view</td><td>3601537</td><td>2053013563810775923</td><td>appliances.kitchen.washer</td><td>samsung</td><td>386.08</td><td>512854725</td><td>923be535-e2ae-4b47-af2d-5f5dad09f0ae</td></tr><tr><td>2019-10-26T07:55:54.000Z</td><td>cart</td><td>16700267</td><td>2053013559901684381</td><td>furniture.kitchen.chair</td><td>null</td><td>13.1</td><td>515802764</td><td>989e824d-3f3f-45a6-9025-4f0e32870e67</td></tr><tr><td>2019-10-26T07:55:55.000Z</td><td>view</td><td>17600213</td><td>2053013558895051365</td><td>null</td><td>missha</td><td>17.37</td><td>523607154</td><td>82514b31-043a-4386-874a-235b7f40b50b</td></tr><tr><td>2019-10-26T07:55:55.000Z</td><td>view</td><td>15300008</td><td>2053013552662315243</td><td>null</td><td>samsung</td><td>43.21</td><td>516470345</td><td>97532507-cf75-429e-8bbd-84c2fc32dab7</td></tr><tr><td>2019-10-26T07:55:55.000Z</td><td>view</td><td>1004858</td><td>2053013555631882655</td><td>electronics.smartphone</td><td>samsung</td><td>131.53</td><td>522850155</td><td>40738b0d-76ac-4e20-8020-045709479161</td></tr><tr><td>2019-10-26T07:55:55.000Z</td><td>view</td><td>1004434</td><td>2053013555631882655</td><td>electronics.smartphone</td><td>samsung</td><td>257.15</td><td>516035121</td><td>238a9215-7c7e-4101-a3f5-abafd893e585</td></tr><tr><td>2019-10-26T07:55:55.000Z</td><td>view</td><td>22700065</td><td>2053013556168753601</td><td>null</td><td>aeroforce</td><td>145.43</td><td>514919831</td><td>71a13977-8ac6-43d5-b261-61293ac7192d</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Validate Time Travel Works

# %%
# %sql
SELECT COUNT(*)
FROM workspace.ecommerce.oct_events_delta_sql VERSION AS OF 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>42448764</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# After the incremental load,
# %sql
SELECT COUNT(*)
FROM workspace.ecommerce.oct_events_delta_sql VERSION AS OF 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>109950743</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Task 3: Optimize Delta Tables

# %% [markdown]
# ## Understand WHY OPTIMIZE is needed
#
# Delta tables often end up with many small files due to:
#
# Frequent appends
#
# MERGE operations
#
# Incremental pipelines
#
# 👉 Small files = slow queries
#
# 👉 OPTIMIZE = compacts files into larger ones

# %% [markdown]
# Run OPTIMIZE (Basic)

# %%
# %sql
OPTIMIZE workspace.ecommerce.oct_events_delta_sql;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(22, 68, List(51069941, 68137411, 5.439848204545455E7, 22, 1196766605), List(1764250, 19282631, 1.72336235E7, 68, 1171886398), 0, null, null, 0, 1, 80, 12, true, 0, 0, 1768474000980, 1768474013805, 8, 22, null, List(0, 0), null, 9, 9, 60667, 0, null)</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Optimize with Z-ORDER (Recommended ⭐)
#
# Use Z-ORDER on columns that are:
#
# Frequently filtered
#
# Used in joins

# %%
# %sql
OPTIMIZE workspace.ecommerce.oct_events_delta_sql
ZORDER BY (user_id, event_time);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(24, 34, List(64703736, 92493347, 7.644601516666667E7, 24, 1834704364), List(51069941, 69911558, 5.6725958205882356E7, 34, 1928682579), 0, List(minCubeSize(107374182400), List(0, 0), List(34, 1928682579), 0, List(34, 1928682579), 1, null), null, 0, 1, 34, 0, false, 0, 0, 1768474077182, 1768474113965, 8, 1, null, List(0, 0), null, 9, 9, 140286, 0, null)</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Best Practices (Remember This )
#
# Run OPTIMIZE:
#
# - After large MERGE operations
#
# - On frequently queried tables
#
# - Don’t run it after every small write
#
# - Use Z-ORDER only on selective columns

# %% [markdown]
# ## Task 4: Clean Old Files (VACUUM)

# %% [markdown]
# Understand What VACUUM Does
#
# After:
#
# MERGE,
# OPTIMIZE,
# DELETE
#
# Delta keeps old files for:
#
# Time travel,
# Rollback,
# Auditing
#
# 👉 VACUUM removes those unused files

# %% [markdown]
# Run VACUUM

# %%
# %sql
VACUUM workspace.ecommerce.oct_events_delta_sql;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td></td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# What this does
#
# Keeps last 7 days of history (default)
#
# Removes older unused files
#
# Safe for most use cases
#
# ✅ Recommended for learning & production

# %% [markdown]
# Verify VACUUM Ran

# %%
# %sql
DESCRIBE HISTORY workspace.ecommerce.oct_events_delta_sql;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>6</td><td>2026-01-15T10:53:49.000Z</td><td>78119440703336</td><td>karthika2738@gmail.com</td><td>VACUUM END</td><td>Map(status -> COMPLETED)</td><td>null</td><td>List(2538393327508024)</td><td>0115-102806-588uh7nr-v2n</td><td>5</td><td>SnapshotIsolation</td><td>true</td><td>Map(numDeletedFiles -> 0, numVacuumedDirectories -> 1)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>5</td><td>2026-01-15T10:53:48.000Z</td><td>78119440703336</td><td>karthika2738@gmail.com</td><td>VACUUM START</td><td>Map(retentionCheckEnabled -> true, defaultRetentionMillis -> 604800000)</td><td>null</td><td>List(2538393327508024)</td><td>0115-102806-588uh7nr-v2n</td><td>4</td><td>SnapshotIsolation</td><td>true</td><td>Map(numFilesToDelete -> 0, sizeOfDataToDelete -> 0)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>4</td><td>2026-01-15T10:48:34.000Z</td><td>78119440703336</td><td>karthika2738@gmail.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> false, clusterBy -> [], zOrderBy -> ["user_id","event_time"], batchId -> 0)</td><td>null</td><td>List(2538393327508024)</td><td>0115-102806-588uh7nr-v2n</td><td>3</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 34, numRemovedBytes -> 1928682579, p25FileSize -> 71158718, numDeletionVectorsRemoved -> 0, minFileSize -> 64703736, numAddedFiles -> 24, maxFileSize -> 92493347, p75FileSize -> 83156540, p50FileSize -> 76117023, numAddedBytes -> 1834704364)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>3</td><td>2026-01-15T10:46:54.000Z</td><td>78119440703336</td><td>karthika2738@gmail.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> false, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(2538393327508024)</td><td>0115-102806-588uh7nr-v2n</td><td>2</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 68, numRemovedBytes -> 1171886398, p25FileSize -> 52907322, numDeletionVectorsRemoved -> 0, minFileSize -> 51069941, numAddedFiles -> 22, maxFileSize -> 68137411, p75FileSize -> 55112855, p50FileSize -> 53386543, numAddedBytes -> 1196766605)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>2</td><td>2026-01-15T10:34:06.000Z</td><td>78119440703336</td><td>karthika2738@gmail.com</td><td>MERGE</td><td>Map(predicate -> ["(((event_time#13201 = event_time#13181) AND (user_id#13208 = user_id#13188)) AND (product_id#13203 = product_id#13183))"], clusterBy -> [], matchedPredicates -> [{"actionType":"update"}], statsOnLoad -> true, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [{"actionType":"insert"}])</td><td>null</td><td>List(2538393327508024)</td><td>0115-102806-588uh7nr-v2n</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 68, numTargetBytesAdded -> 1171886398, numTargetBytesRemoved -> 0, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 0, executionTimeMs -> 84187, materializeSourceTimeMs -> 45304, numTargetRowsInserted -> 67501979, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 18575, numTargetRowsUpdated -> 0, numOutputRows -> 67501979, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 67501979, numTargetFilesRemoved -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 20165)</td><td>null</td><td>Databricks ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Understand Retention Policy
#
# Default retention:
#
# 7 days (168 hours)
#
#
# Meaning:
#
# Time travel works for last 7 days
#
# Older versions are removed

# %% [markdown]
# Best Practices
#
# ✔ Use default VACUUM in production
#
# ✔ Run VACUUM after OPTIMIZE
#
# ✔ Never run RETAIN 0 HOURS accidentally
#
# ✔ Schedule VACUUM off-peak
