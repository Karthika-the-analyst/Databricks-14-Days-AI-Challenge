# %% [markdown]
# ### 🛠️ 10 Tasks:
#
# 1. Analyze query plans
# 2. Partition large tables
# 3. Apply ZORDER
# 4. Benchmark improvements

# %% [markdown]
# ## Task 1: Analyze Query Plan

# %% [markdown]
# Pick a Query to Analyze
#
# Use EXPLAIN (Logical + Physical Plan)

# %%
# %sql
EXPLAIN
SELECT
  order_date,
  total_revenue
FROM ecommerce_catalog.gold.daily_sales
WHERE order_date >= '2019-10-01'
ORDER BY order_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>plan</th></tr></thead><tbody><tr><td>== Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonSort [order_date#13171 ASC NULLS FIRST]
#          +- PhotonScan parquet ecommerce_catalog.gold.daily_sales[order_date#13171,total_revenue#13172] DataFilters: [isnotnull(order_date#13171), (order_date#13171 >= 2019-10-01)], DictionaryFilters: [(order_date#13171 >= 2019-10-01)], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-g9urr/uc/c4d0d19d-f1d2-4e1a-afbd-94a246ba7d40..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<order_date:date,total_revenue:double>, RequiredDataFilters: [isnotnull(order_date#13171), (order_date#13171 >= 2019-10-01)]
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = daily_sales
# </td></tr></tbody></table></div>

# %% [markdown]
# ## Task 2: Partition Large Tables

# %% [markdown]
# Partitioning helps:
#
# Reduce scanned files
#
# Enable partition pruning
#
# Improve query speed on filters
#
# 👉 We partition on high-cardinality filter columns used in WHERE

# %% [markdown]
# Recreate Gold Table with Partition

# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_catalog.gold.daily_sales_partitioned
PARTITIONED BY (order_date)
AS
SELECT *
FROM ecommerce_catalog.gold.daily_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Verify Partitioning

# %%
# %sql
DESCRIBE DETAIL ecommerce_catalog.gold.daily_sales_partitioned;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th><th>clusterByAuto</th></tr></thead><tbody><tr><td>delta</td><td>2cbd6339-a797-48cb-b238-adc43cbe348f</td><td>ecommerce_catalog.gold.daily_sales_partitioned</td><td>null</td><td></td><td>2026-01-20T17:13:00.714Z</td><td>2026-01-20T17:13:09.000Z</td><td>List(order_date)</td><td>List()</td><td>61</td><td>81237</td><td>Map(delta.parquet.compression.codec -> zstd, delta.enableDeletionVectors -> true)</td><td>3</td><td>7</td><td>List(appendOnly, deletionVectors, invariants)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# ##Task 3: Apply Z-ORDER

# %% [markdown]
# We already did partitioning ✅
# But partitioning alone is not enough when:
#
# Queries filter on non-partition columns
#
# Data inside a partition is still large
#
# You want faster data skipping
#
# 👉 Z-ORDER improves data skipping inside partitions

# %% [markdown]
# Apply Z-ORDER

# %%
# %sql
OPTIMIZE ecommerce_catalog.gold.daily_sales_partitioned
ZORDER BY (total_revenue);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 61, List(minCubeSize(107374182400), List(0, 0), List(61, 81237), 0, List(0, 0), 0, null), null, 0, 0, 61, 61, false, 0, 0, 1768929654732, 1768929658920, 8, 0, null, List(0, 0), null, 4, 4, 0, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# Re-run EXPLAIN (Validation)

# %%
# %sql
EXPLAIN
SELECT
  order_date,
  total_revenue
FROM ecommerce_catalog.gold.daily_sales_partitioned
WHERE order_date >= '2019-10-01'
ORDER BY order_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>plan</th></tr></thead><tbody><tr><td>== Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonSort [order_date#13785 ASC NULLS FIRST]
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#8930]
#                +- PhotonShuffleExchangeSink rangepartitioning(order_date#13785 ASC NULLS FIRST, 1024)
#                   +- PhotonProject [order_date#13785, total_revenue#13786]
#                      +- PhotonScan parquet ecommerce_catalog.gold.daily_sales_partitioned[total_revenue#13786,order_date#13785] DataFilters: [], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-g9urr/uc/c4d0d19d-f1d2-4e1a-afbd-94a246ba7d40..., OptionalDataFilters: [], PartitionFilters: [isnotnull(order_date#13785), (order_date#13785 >= 2019-10-01)], ReadSchema: struct<total_revenue:double>, RequiredDataFilters: []
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial = daily_sales_partitioned
#   full    =
# Corrective actions: consider running the following command on all tables with missing or partial statistics
#   ANALYZE TABLE <table-name> COMPUTE STATISTICS FOR ALL COLUMNS
# </td></tr></tbody></table></div>

# %% [markdown]
# 🔍 What improved
#
# ✔ Partition pruning (order_date)
#
# ✔ Data skipping (total_revenue)
#
# ✔ Fewer files scanned
#
# ✔ Faster execution

# %% [markdown]
# ## Task 4: Benchmark Improvements
# We now compare BEFORE vs AFTER

# %% [markdown]
# Capture BEFORE metrics (unpartitioned table)

# %%
# %sql
SELECT
  order_date,
  total_revenue
FROM ecommerce_catalog.gold.daily_sales
WHERE order_date >= '2019-10-01'
ORDER BY order_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_date</th><th>total_revenue</th></tr></thead><tbody><tr><td>2019-10-01</td><td>3.7063524225992954E8</td></tr><tr><td>2019-10-02</td><td>3.5757353882987684E8</td></tr><tr><td>2019-10-03</td><td>3.394813026499579E8</td></tr><tr><td>2019-10-04</td><td>4.236928194202042E8</td></tr><tr><td>2019-10-05</td><td>3.956764972899051E8</td></tr><tr><td>2019-10-06</td><td>3.97025067050164E8</td></tr><tr><td>2019-10-07</td><td>3.554490384999612E8</td></tr><tr><td>2019-10-08</td><td>3.808717091899185E8</td></tr><tr><td>2019-10-09</td><td>3.7977535402009356E8</td></tr><tr><td>2019-10-10</td><td>3.7205491930024576E8</td></tr><tr><td>2019-10-11</td><td>4.217817924698372E8</td></tr><tr><td>2019-10-12</td><td>4.1720415515987176E8</td></tr><tr><td>2019-10-13</td><td>4.582179037198206E8</td></tr><tr><td>2019-10-14</td><td>4.335453156395588E8</td></tr><tr><td>2019-10-15</td><td>4.565663768899684E8</td></tr><tr><td>2019-10-16</td><td>4.4308661572993654E8</td></tr><tr><td>2019-10-17</td><td>4.1104202922971666E8</td></tr><tr><td>2019-10-18</td><td>4.263086272200598E8</td></tr><tr><td>2019-10-19</td><td>4.1906434100973386E8</td></tr><tr><td>2019-10-20</td><td>4.3647061379982907E8</td></tr><tr><td>2019-10-21</td><td>4.0201956546041673E8</td></tr><tr><td>2019-10-22</td><td>4.07140359839765E8</td></tr><tr><td>2019-10-23</td><td>3.963132877699827E8</td></tr><tr><td>2019-10-24</td><td>3.834812229600678E8</td></tr><tr><td>2019-10-25</td><td>4.1194531613002336E8</td></tr><tr><td>2019-10-26</td><td>3.9009408163999903E8</td></tr><tr><td>2019-10-27</td><td>4.0701580600013554E8</td></tr><tr><td>2019-10-28</td><td>3.6379608277997565E8</td></tr><tr><td>2019-10-29</td><td>3.530465563401557E8</td></tr><tr><td>2019-10-30</td><td>3.495820899198324E8</td></tr><tr><td>2019-10-31</td><td>3.6392292780981696E8</td></tr><tr><td>2019-11-01</td><td>4.256995272597517E8</td></tr><tr><td>2019-11-02</td><td>4.548500359902197E8</td></tr><tr><td>2019-11-03</td><td>4.670946039003023E8</td></tr><tr><td>2019-11-04</td><td>5.317783626001338E8</td></tr><tr><td>2019-11-05</td><td>4.952876358199117E8</td></tr><tr><td>2019-11-06</td><td>4.8967452394024014E8</