# %% [markdown]
# ### 🛠️  Day 11 Tasks:
#
# 1. Calculate statistical summaries
# 2. Test hypotheses (weekday vs weekend)
# 3. Identify correlations
# 4. Engineer features for ML

# %% [markdown]
# ## Task 1: Calculate Statistical Summaries

# %% [markdown]
# Basic Statistics (Revenue)

# %%
# %sql
SELECT
  COUNT(*)                      AS days_count,
  MIN(total_revenue)            AS min_revenue,
  MAX(total_revenue)            AS max_revenue,
  AVG(total_revenue)            AS avg_revenue,
  STDDEV(total_revenue)         AS stddev_revenue
FROM ecommerce_catalog.gold.daily_sales_partitioned;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>days_count</th><th>min_revenue</th><th>max_revenue</th><th>avg_revenue</th><th>stddev_revenue</th></tr></thead><tbody><tr><td>61</td><td>3.394813026499579E8</td><td>1.998441656940825E9</td><td>5.2566333116608614E8</td><td>3.3489443033665925E8</td></tr></tbody></table></div>

# %% [markdown]
# Distribution Check (Orders)

# %%
# %sql
SELECT
  MIN(total_orders)  AS min_orders,
  MAX(total_orders)  AS max_orders,
  AVG(total_orders)  AS avg_orders
FROM ecommerce_catalog.gold.daily_sales_partitioned;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min_orders</th><th>max_orders</th><th>avg_orders</th></tr></thead><tbody><tr><td>1125950</td><td>6460123</td><td>1798262.0</td></tr></tbody></table></div>

# %% [markdown]
# ## Task 2: Hypothesis Testing (Weekday vs Weekend)

# %% [markdown]
# Create Weekday / Weekend Label

# %%
# %sql
SELECT
  CASE 
    WHEN dayofweek(order_date) IN (1, 7) THEN 'Weekend'
    ELSE 'Weekday'
  END AS day_type,
  AVG(total_revenue) AS avg_revenue
FROM ecommerce_catalog.gold.daily_sales_partitioned
GROUP BY day_type;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>day_type</th><th>avg_revenue</th></tr></thead><tbody><tr><td>Weekday</td><td>4.875411480416197E8</td></tr><tr><td>Weekend</td><td>6.243325110176462E8</td></tr></tbody></table></div>

# %% [markdown]
# Average revenue on weekends > average revenue on weekdays
#
# This confirms the hypothesis that customers spend more on weekends.

# %% [markdown]
# ## Task 3: Identify Correlations

# %% [markdown]
# Correlation Calculation

# %%
# %sql
SELECT
  CORR(total_orders, total_revenue) AS orders_revenue_corr
FROM ecommerce_catalog.gold.daily_sales_partitioned;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>orders_revenue_corr</th></tr></thead><tbody><tr><td>0.9984075739818076</td></tr></tbody></table></div>

# %% [markdown]
# The correlation between total orders and total revenue is extremely high (~0.998), indicating that order volume is the primary driver of revenue. This validates that increasing customer conversions directly impacts revenue growth.

# %% [markdown]
# ## Task 4: Feature Engineering for ML

# %% [markdown]
# Create Feature Table

# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_catalog.gold.daily_sales_features AS
SELECT
  order_date,
  dayofweek(order_date)                AS day_of_week,
  CASE 
    WHEN dayofweek(order_date) IN (1,7) THEN 1 ELSE 0 
  END                                  AS is_weekend,
  total_orders,
  total_revenue,
  avg_order_value,
  LAG(total_revenue, 1) OVER (ORDER BY order_date) AS prev_day_revenue
FROM ecommerce_catalog.gold.daily_sales_partitioned;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>
